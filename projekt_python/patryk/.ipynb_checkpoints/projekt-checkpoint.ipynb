# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition_v2.csv')

df2 = pd.get_dummies(df["Gender"])
df["GenderNumeric"] = df2["Male"]

df2 = pd.get_dummies(df["OverTime"])
df["OverTimeNumeric"] = df2["Yes"]

pd.set_option('display.max_column',30)
pd.set_option('display.max_rows',10)
pd.set_option('display.max_seq_items',None)
pd.set_option('display.max_colwidth', 500)
pd.set_option('expand_frame_repr', True)

df.head()
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   41      Travel_Rarely                   Sales                 1
# 1   49  Travel_Frequently  Research & Development                 8
# 2   37      Travel_Rarely  Research & Development                 2
# 3   33  Travel_Frequently  Research & Development                 3
# 4   27      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# 0          2  Life Sciences                        2  Female               3
# 1          1  Life Sciences                        3    Male               2
# 2          2          Other                        4    Male               2
# 3          4  Life Sciences                        4  Female               3
# 4          1        Medical                        1    Male               3
#
#    JobLevel                JobRole  JobSatisfaction MaritalStatus  \
# 0         2        Sales Executive                4        Single
# 1         2     Research Scientist                2       Married
# 2         1  Laboratory Technician                3        Single
# 3         1     Research Scientist                3       Married
# 4         1  Laboratory Technician                2       Married
#
#    MonthlyIncome  NumCompaniesWorked OverTime  PerformanceRating  \
# 0           5993                   8      Yes                  3
# 1           5130                   1       No                  4
# 2           2090                   6      Yes                  3
# 3           2909                   1      Yes                  3
# 4           3468                   9       No                  3
#
#    RelationshipSatisfaction  TotalWorkingYears  TrainingTimesLastYear  \
# 0                         1                  8                      0
# 1                         4                 10                      3
# 2                         2                  7                      3
# 3                         3                  8                      3
# 4                         4                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager  GenderNumeric  \
# 0                        0                     5              0
# 1                        1                     7              1
# 2                        0                     0              1
# 3                        3                     0              0
# 4                        2                     2              1
#
#    OverTimeNumeric
# 0                1
# 1                0
# 2                1
# 3                1
# 4                0

# %%
corr = df.corr()
corr

# %%
sns.set(font_scale=1.4)
fig, (ax) = plt.subplots(figsize=(20,15))
matrix = sns.heatmap(corr, 
                 ax=ax,
                 cmap="coolwarm",
                 annot=True,
                 fmt='.2f',
                 annot_kws={"size": 15},
                 linewidths=.05)

# %%
kolumna1 = input('Podaj kolumnę: ')

df_col = df[kolumna1]
df_col

# %%
kolumna2 = input('Podaj kolumnę: ')
wartosc = int(input('Podaj wartość: '))
df3 = df
df3['Count'] = df.groupby(kolumna2)[kolumna2].transform(len)

try:
    df4 = df3[df[kolumna2]==wartosc]
    if len(df4.index) == 0:
        raise ValueError
except ValueError:
    df4 = df3.iloc[(df[kolumna2] - wartosc).abs().argsort()[:1]]
    zakres = df5['Count'].values[0]
    df4 = df3.iloc[(df[kolumna2] - wartosc).abs().argsort()[:zakres]]
df_row = df4.drop('Count', axis = 1)
df_row
# Out:
# Podaj kolumnę: Age
# Podaj wartość: 22
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 17     22         Non-Travel  Research & Development                16
# 109    22      Travel_Rarely  Research & Development                15
# 128    22      Travel_Rarely  Research & Development                 2
# 160    22      Travel_Rarely  Research & Development                19
# 206    22      Travel_Rarely  Research & Development                 5
# ...   ...                ...                     ...               ...
# 860    22  Travel_Frequently  Research & Development                 3
# 1137   22         Non-Travel  Research & Development                26
# 1273   22      Travel_Rarely  Research & Development                 8
# 1339   22      Travel_Rarely  Research & Development                 7
# 1423   22      Travel_Rarely  Research & Development                 1
#
#       Education    EducationField  EnvironmentSatisfaction  Gender  \
# 17            2           Medical                        4    Male
# 109           3           Medical                        2  Female
# 128           1  Technical Degree                        3    Male
# 160           1           Medical                        3    Male
# 206           3     Life Sciences                        4    Male
# ...         ...               ...                      ...     ...
# 860           4     Life Sciences                        3    Male
# 1137          2             Other                        2  Female
# 1273          1           Medical                        3  Female
# 1339          1     Life Sciences                        4    Male
# 1423          2     Life Sciences                        4    Male
#
#       JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 17                 4         1  Laboratory Technician                4
# 109                3         1  Laboratory Technician                4
# 128                3         1  Laboratory Technician                4
# 160                3         1     Research Scientist                4
# 206                4         1     Research Scientist                2
# ...              ...       ...                    ...              ...
# 860                2         1     Research Scientist                4
# 1137               2         1     Research Scientist                3
# 1273               3         1  Laboratory Technician                1
# 1339               3         1     Research Scientist                2
# 1423               3         1     Research Scientist                3
#
#      MaritalStatus  MonthlyIncome  NumCompaniesWorked OverTime  \
# 17        Divorced           2935                   1      Yes
# 109         Single           2871                   1       No
# 128        Married           2523                   0       No
# 160        Married           2323                   1       No
# 206       Divorced           2328                   1      Yes
# ...            ...            ...                 ...      ...
# 860        Married           2853                   0      Yes
# 1137       Married           2814                   1      Yes
# 1273       Married           2398                   1      Yes
# 1339        Single           2472                   1      Yes
# 1423        Single           3375                   0       No
#
#       PerformanceRating  RelationshipSatisfaction  TotalWorkingYears  \
# 17                    3                         2                  1
# 109                   3                         3                  1
# 128                   3                         3                  3
# 160                   4                         1                  2
# 206                   3                         1                  4
# ...                 ...                       ...                ...
# 860                   3                         2                  1
# 1137                  3                         2                  4
# 1273                  3                         3                  1
# 1339                  4                         1                  1
# 1423                  3                         4                  4
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 17                        2                2               1
# 109                       5                3               0
# 128                       2                3               2
# 160                       6                3               2
# 206                       2                2               4
# ...                     ...              ...             ...
# 860                       5                3               0
# 1137                      2                2               4
# 1273                      6                3               1
# 1339                      2                3               1
# 1423                      2                4               3
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 17                     0                        0                     0
# 109                    0                        0                     0
# 128                    1                        2                     1
# 160                    2                        2                     2
# 206                    2                        2                     2
# ...                  ...                      ...                   ...
# 860                    0                        0                     0
# 1137                   2                        1                     3
# 1273                   0                        0                     0
# 1339                   0                        0                     0
# 1423                   2                        1                     2
#
#       GenderNumeric  OverTimeNumeric
# 17                1                1
# 109               0                0
# 128               1                0
# 160               1                0
# 206               1                1
# ...             ...              ...
# 860               1                1
# 1137              0                1
# 1273              0                1
# 1339              1                1
# 1423              1                0
#
# [16 rows x 27 columns]
