# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("D:\infoShare\git\jdsz3-fajni\projekt_python\WA_Fn-UseC_-HR-Employee-Attrition_v2.csv")
df
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      41      Travel_Rarely                   Sales                 1
# 1      49  Travel_Frequently  Research & Development                 8
# 2      37      Travel_Rarely  Research & Development                 2
# 3      33  Travel_Frequently  Research & Development                 3
# 4      27      Travel_Rarely  Research & Development                 2
# 5      32  Travel_Frequently  Research & Development                 2
# 6      59      Travel_Rarely  Research & Development                 3
# 7      30      Travel_Rarely  Research & Development                24
# 8      38  Travel_Frequently  Research & Development                23
# 9      36      Travel_Rarely  Research & Development                27
# 10     35      Travel_Rarely  Research & Development                16
# 11     29      Travel_Rarely  Research & Development                15
# ...

# %%
corr = df.corr()
corr
# Out:
#                                Age  DistanceFromHome  Education  \
# Age                       1.000000         -0.001686   0.208034
# DistanceFromHome         -0.001686          1.000000   0.021042
# Education                 0.208034          0.021042   1.000000
# EnvironmentSatisfaction   0.010146         -0.016075  -0.027128
# JobInvolvement            0.029820          0.008783   0.042438
# JobLevel                  0.509604          0.005303   0.101589
# JobSatisfaction          -0.004892         -0.003669  -0.011296
# MonthlyIncome             0.497855         -0.017014   0.094961
# NumCompaniesWorked        0.299635         -0.029251   0.126317
# PerformanceRating         0.001904          0.027110  -0.024539
# RelationshipSatisfaction  0.053535          0.006557  -0.009118
# TotalWorkingYears         0.680381          0.004628   0.148280
# TrainingTimesLastYear    -0.019621         -0.036942  -0.025100
# WorkLifeBalance          -0.021490         -0.026556   0.009819
# ...

# %%
sns.set(font_scale=1.4)
fig, (ax) = plt.subplots(figsize=(20,15))
matrix = sns.heatmap(corr, 
                 ax=ax,
                 cmap="coolwarm",
                 annot=True,
                 fmt='.2f',
                 annot_kws={"size": 15},
                 linewidths=.05)
